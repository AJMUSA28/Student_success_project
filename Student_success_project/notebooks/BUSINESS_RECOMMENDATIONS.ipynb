# %% [markdown]
# # 📈  BUSINESS RECOMMENDATIONS

# %% [markdown]
# ****🚨 1. High Churn risk is concentrated****

# %% [markdown]
# Courses 1 and 7 are major churn drivers
#
# 📌 Executive Insight
# “Significant variation exists in student success rates across courses. Courses 12 and 10 demonstrate the highest ROI with graduation rates above 70%, while courses 1 and 7 show critically low completion rates below 10%, indicating potential issues in curriculum design, student engagement, or support systems.”

# %% [markdown]
# ****🎯 2. Which track has best ROI?****

# %% [markdown]
# 🎯 KEY INSIGHT
# 🟢 HIGH ROI COURSES (Top Performers)
#
# These courses have high graduation rates:
#
# Course 12 → 71.5% ✅
# Course 10 → 69.8% ✅
# Course 15 → 59.2%
# Course 5 → 58.8%
#
# 👉 Interpretation:
# Students in these courses are more likely to succeed
# These courses deliver high value (ROI)
#
#
# 🔴 LOW ROI COURSES (Problem Areas)
# Course 1 → 8.3% ❌
# Course 7 → 8.2% ❌
# Course 16 → 29.6%
# Course 17 → 29.1%
#
# 👉 Interpretation:
# Very high dropout or non-completion
# These courses are high-risk / low ROI
#
# 📊 WHAT THIS SUGGESTS (VERY IMPORTANT)
# 🧠 1. Course quality / difficulty varies significantly
# Some courses are well-structured
# Others may be:
# Too difficult
# Poorly taught
# Misaligned with student expectations
#
# 💰 2. ROI is NOT equal across courses
# Investing equally in all courses is inefficient
# Some courses yield much better outcomes
#
# 🚀 ACTIONABLE RECOMMENDATIONS
#
# 🎯 1. Invest in High ROI Courses
# Increase funding for:
# Course 12
# Course 10
#
# 👉 Actions:
# Expand enrollment capacity
# Increase marketing budget
#
# 🎯 2. Fix or Review Low ROI Courses
# Focus on:
# Course 1
# Course 7
#
# 👉 Actions:
# Review curriculum
# Improve teaching methods
# Add student support programs
#
# 🎯 3. Early Warning System
# Students in low ROI courses are high churn risk
#
# 👉 Action:
# Monitor performance early (first semester)

# %% [markdown]
# **🎯3. What Drives Course Completion?**

# %% [markdown]
# Course completion (Graduation) is mainly driven by a combination of academic performance, engagement, and financial stability.
# We determine this from patterns like correlation, groupby analysis, and feature importance.
#
#
# 📊 1. STRONGEST DRIVERS (MOST IMPORTANT)
#
# 🧠 A. Academic Performance (MOST IMPORTANT 🔥)
# Key features:
# Curricular units 2nd sem (approved)
# Curricular units 2nd sem (grade)
# Curricular units 1st sem (approved)
# 👉 Insight:
# Students who pass more courses → much higher graduation rate
# Second semester performance is especially critical
#
# 🕒 B. Student Engagement
# Key features:
# Course attendance (Daytime/evening attendance)
# Evaluations completed
# Enrolled vs approved units
# 👉 Insight:
# Higher engagement = higher completion probability
# Low participation → strong dropout signal
#
# 💰 C. Financial Stability
# Key features:
# Tuition fees up to date
# Debtor
# Scholarship holder
# 👉 Insight:
# Students with unpaid fees are much more likely to drop out
# Scholarships significantly increase completion rate
#
# 📚 D. Course Structure (Your ROI finding)
# Key feature:
# Course
# 👉 Insight:
# Some courses naturally have higher completion rates
# Example:
# Course 12 → high completion
# Course 7 → very low completion
#
# 👤 E. Student Background Factors
# Key features:
# Age at enrollment
# Mother/Father education
# Previous qualification
# 👉 Insight:
# Younger students + higher education background → slightly higher success rates
#
# 📈 2. WHAT YOUR DATA IS SAYING (SUMMARY)
#
# 👉 Course completion is mainly driven by:
# 🔥 TOP 3 DRIVERS:
# Second semester academic performance
# Tuition/payment status
# Course type (program difficulty/structure)
#
# 🧠 3. SIMPLE BUSINESS INTERPRETATION
# “Course completion is primarily influenced by academic performance in the second semester, financial readiness (tuition payment and scholarships), and the specific course enrolled. Students with higher academic engagement and financial stability are significantly more likely to graduate.”
#
# 🚨 4. CHURN RISK PATTERN (VERY IMPORTANT)
# Students likely to NOT complete course:
#
# Low grades in semester 2
# Unpaid tuition
# Low number of approved units
# Enrolled in low-performing courses

# %% [markdown]
# ****🎯 4. Marketing Strategy****

# %% [markdown]
# Promote high-performing courses
# Reduce advertising for poor-performing ones (until fixed)
